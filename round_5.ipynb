# %%
from src.model_predict import forecast_future
from src.preprocessing import load_data, split_data, split_processed_data
from src.forecasting import RollingForecaster
from src.feature_engineering import create_features
from src.model_fit import train_models

import warnings
warnings.filterwarnings("ignore")
# Out:
# C:\Users\Mariooo\AppData\Local\Temp\tmpyouh725s 32768 tmpyouh725s

# %%
data_dict = load_data('data/round_5/*.xlsx')

# %%
data_dict
# Out:
# {'Hong Kong International Airport':           Date  Total
#  0   2023-01-08  30275
#  1   2023-01-09  24796
#  2   2023-01-10  24012
#  3   2023-01-11  23273
#  4   2023-01-12  23053
#  ..         ...    ...
#  821 2025-04-08  60797
#  822 2025-04-09  54164
#  823 2025-04-10  55832
#  824 2025-04-11  64252
#  825 2025-04-12  62073
#
#  [826 rows x 2 columns],
#  'Hong Kong-Zhuhai-Macao Bridge':           Date  Total
#  0   2023-01-08   5321
#  1   2023-01-09   4937
#  2   2023-01-10   5617
#  3   2023-01-11   6191
#  4   2023-01-12   6699
#  ..         ...    ...
#  821 2025-04-08  28809
#  822 2025-04-09  28309
#  823 2025-04-10  28153
#  824 2025-04-11  31023
#  825 2025-04-12  34587
#
#  [826 rows x 2 columns],
#  'Lo Wu':           Date  Total
#  0   2023-02-06  30319
#  1   2023-02-07  32954
#  2   2023-02-08  35022
#  3   2023-02-09  34764
#  4   2023-02-10  39235
#  ..         ...    ...
#  792 2025-04-08  82638
#  793 2025-04-09  81359
#  794 2025-04-10  80281
#  795 2025-04-11  82676
#  796 2025-04-12  81797
#
#  [797 rows x 2 columns],
#  'Lok Ma Chau Spur Line':           Date  Total
#  0   2023-01-08   5680
#  1   2023-01-09   6455
#  2   2023-01-10   7910
#  3   2023-01-11   8594
#  4   2023-01-12  10113
#  ..         ...    ...
#  821 2025-04-08  68143
#  822 2026-04-09  66844
#  823 2025-04-10  65681
#  824 2025-04-11  68887
#  825 2025-04-12  68802
#
#  [826 rows x 2 columns],
#  'Shenzhen Bay':           Date  Total
#  0   2023-01-08   3543
#  1   2023-01-09   3265
#  2   2023-01-10   3930
#  3   2023-01-11   4271
#  4   2023-01-12   5030
#  ..         ...    ...
#  821 2025-04-08  49906
#  822 2025-04-09  47487
#  823 2025-04-10  50984
#  824 2025-04-11  53957
#  825 2025-04-12  51832
#
#  [826 rows x 2 columns]}

# %%
processed_data_dict = {}
df_dict = {}
for name, data in data_dict.items():
    df ,processed_data = create_features(data)
    df_dict[name] = df
    processed_data_dict[name] = processed_data
# Out:
# 日期超出范围警告: 2026-04-09 00:00:00 - no available data for year 2026, only year between [2004, 2025] supported

# %%
processed_data_dict['Lo Wu']
# Out:
#           Date   Total  year  month  day  weekday  quarter  is_weekend  \
# 60  2023-04-07   67296  2023      4    7        4        2           0
# 61  2023-04-08   81440  2023      4    8        5        2           1
# 62  2023-04-09  111824  2023      4    9        6        2           1
# 63  2023-04-10  121590  2023      4   10        0        2           0
# 64  2023-04-11   69794  2023      4   11        1        2           0
# ..         ...     ...   ...    ...  ...      ...      ...         ...
# 792 2025-04-08   82638  2025      4    8        1        2           0
# 793 2025-04-09   81359  2025      4    9        2        2           0
# 794 2025-04-10   80281  2025      4   10        3        2           0
# 795 2025-04-11   82676  2025      4   11        4        2           0
# 796 2025-04-12   81797  2025      4   12        5        2           1
#
#      is_hk_holiday  is_cn_holiday  ...  rolling_30_mean  ma_ratio_7_30  \
# 60            True          False  ...     59054.600000       0.957654
# 61            True           True  ...     59544.100000       0.978830
# 62            True           True  ...     60441.333333       1.010668
# 63            True          False  ...     62213.966667       1.075167
# 64           False          False  ...     64050.366667       1.206029
# ..             ...            ...  ...              ...            ...
# 792          False          False  ...     95069.866667       1.046489
# 793          False          False  ...     93232.500000       1.081464
# 794          False          False  ...     92987.233333       1.094442
# 795          False          False  ...     92956.000000       1.101655
# 796          False           True  ...     93117.033333       1.029677
#
#      month_sin  month_cos  quarter_sin  quarter_cos  days_since_start  \
# 60    0.866025       -0.5     0.866025          0.5                60
# 61    0.866025       -0.5     0.866025          0.5                61
# 62    0.866025       -0.5     0.866025          0.5                62
# 63    0.866025       -0.5     0.866025          0.5                63
# 64    0.866025       -0.5     0.866025          0.5                64
# ..         ...        ...          ...          ...               ...
# 792   0.866025       -0.5     0.866025          0.5               792
# 793   0.866025       -0.5     0.866025          0.5               793
# 794   0.866025       -0.5     0.866025          0.5               794
# 795   0.866025       -0.5     0.866025          0.5               795
# 796   0.866025       -0.5     0.866025          0.5               796
#
#      days_squared  weekly_growth  monthly_growth
# 60           3600       0.946751        1.735249
# 61           3721       0.984787        1.654518
# 62           3844       0.920830        1.674519
# 63           3969       0.926516        1.912841
# 64           4096       0.823357        2.261221
# ..            ...            ...             ...
# 792        627264       0.921290        1.752347
# 793        628849       0.947318        0.960952
# 794        630436       0.952972        0.719456
# 795        632025       1.565046        0.976064
# 796        633616       1.144196        1.101841
#
# [737 rows x 210 columns]

# %%
df_dict
# Out:
# {'Hong Kong International Airport':           Date  Total      ex  hk_sum  hk_pc  hk_mobile  hk_food_sum  \
#  60  2023-03-09  31792  0.8870    8193   1315       6878          348
#  61  2023-03-10  33559  0.8797    8289   1388       6901          294
#  62  2023-03-11  33421  0.8797    8695    948       7747          306
#  63  2023-03-12  37163  0.8797    8483    930       7553          315
#  64  2023-03-13  35531  0.8727    8215   1493       6722          355
#  ..         ...    ...     ...     ...    ...        ...          ...
#  821 2025-04-08  60797  0.9444    5245    957       4288          261
#  822 2025-04-09  54164  0.9444    4868   1017       3851          221
#  823 2025-04-10  55832  0.9444    4985    981       4004          264
#  824 2025-04-11  64252  0.9444    4644    935       3709          219
#  825 2025-04-12  62073  0.9444    5116    741       4375          242
#
#       hk_food_pc  hk_food_mobile  hk_hotel_sum  ...  rolling_30_mean  \
#  60          101             247           276  ...     29064.900000
#  61           99             195           255  ...     29293.933333
#  62           78             228           253  ...     29564.633333
#  63           91             224           233  ...     29820.866667
#  64          123             232           305  ...     30188.000000
#  ..          ...             ...           ...  ...              ...
#  821          97             164           195  ...     59456.166667
#  822          82             139           201  ...     59406.366667
#  823         125             139           202  ...     59300.966667
#  824          70             149           182  ...     59451.300000
#  825          82             160           182  ...     59950.600000
#
#       ma_ratio_7_30  month_sin     month_cos  quarter_sin  quarter_cos  \
#  60        1.050850   1.000000  6.123234e-17     0.500000     0.866025
#  61        1.052841   1.000000  6.123234e-17     0.500000     0.866025
#  62        1.057518   1.000000  6.123234e-17     0.500000     0.866025
#  63        1.067268   1.000000  6.123234e-17     0.500000     0.866025
#  64        1.068480   1.000000  6.123234e-17     0.500000     0.866025
#  ..             ...        ...           ...          ...          ...
#  821       1.032309   0.866025 -5.000000e-01     0.866025     0.500000
#  822       1.053269   0.866025 -5.000000e-01     0.866025     0.500000
#  823       1.059807   0.866025 -5.000000e-01     0.866025     0.500000
#  824       1.048126   0.866025 -5.000000e-01     0.866025     0.500000
#  825       1.048754   0.866025 -5.000000e-01     0.866025     0.500000
#
#       days_since_start  days_squared  weekly_growth  monthly_growth
#  60                 60          3600       1.021040        0.823154
#  61                 61          3721       0.970993        1.025891
#  62                 62          3844       0.902881        1.071714
#  63                 63          3969       0.996296        1.123577
#  64                 64          4096       0.948146        1.173123
#  ..                ...           ...            ...             ...
#  821               821        674041       0.923533        0.843960
#  822               822        675684       0.891124        0.816040
#  823               823        677329       1.027685        0.665612
#  824               824        678976       0.939730        0.711205
#  825               825        680625       0.916563        0.866243
#
#  [766 rows x 239 columns],
#  'Hong Kong-Zhuhai-Macao Bridge':           Date  Total      ex  hk_sum  hk_pc  hk_mobile  hk_food_sum  \
#  60  2023-03-09  20927  0.8870    8193   1315       6878          348
#  61  2023-03-10  23330  0.8797    8289   1388       6901          294
#  62  2023-03-11  30766  0.8797    8695    948       7747          306
#  63  2023-03-12  49453  0.8797    8483    930       7553          315
#  64  2023-03-13  25055  0.8727    8215   1493       6722          355
#  ..         ...    ...     ...     ...    ...        ...          ...
#  821 2025-04-08  28809  0.9444    5245    957       4288          261
#  822 2025-04-09  28309  0.9444    4868   1017       3851          221
#  823 2025-04-10  28153  0.9444    4985    981       4004          264
#  824 2025-04-11  31023  0.9444    4644    935       3709          219
#  825 2025-04-12  34587  0.9444    5116    741       4375          242
#
#       hk_food_pc  hk_food_mobile  hk_hotel_sum  ...  rolling_30_mean  \
#  60          101             247           276  ...     23836.933333
#  61           99             195           255  ...     24025.200000
#  62           78             228           253  ...     24301.866667
#  63           91             224           233  ...     24804.666667
#  64          123             232           305  ...     25821.800000
#  ..          ...             ...           ...  ...              ...
#  821          97             164           195  ...     39165.666667
#  822          82             139           201  ...     37998.733333
#  823         125             139           202  ...     37721.833333
#  824          70             149           182  ...     37710.266667
#  825          82             160           182  ...     37813.166667
#
#       ma_ratio_7_30  month_sin     month_cos  quarter_sin  quarter_cos  \
#  60        1.075174   1.000000  6.123234e-17     0.500000     0.866025
#  61        1.077309   1.000000  6.123234e-17     0.500000     0.866025
#  62        1.069953   1.000000  6.123234e-17     0.500000     0.866025
#  63        1.055262   1.000000  6.123234e-17     0.500000     0.866025
#  64        1.036937   1.000000  6.123234e-17     0.500000     0.866025
#  ..             ...        ...           ...          ...          ...
#  821       1.132231   0.866025 -5.000000e-01     0.866025     0.500000
#  822       1.173934   0.866025 -5.000000e-01     0.866025     0.500000
#  823       1.190705   0.866025 -5.000000e-01     0.866025     0.500000
#  824       1.189551   0.866025 -5.000000e-01     0.866025     0.500000
#  825       1.105189   0.866025 -5.000000e-01     0.866025     0.500000
#
#       days_since_start  days_squared  weekly_growth  monthly_growth
#  60                 60          3600       0.993309        2.871453
#  61                 61          3721       1.029284        3.044359
#  62                 62          3844       0.922863        2.791882
#  63                 63          3969       0.996696        3.059118
#  64                 64          4096       0.918003        3.853112
#  ..                ...           ...            ...             ...
#  821               821        674041       0.922732        1.769549
#  822               822        675684       0.911264        0.859147
#  823               823        677329       0.996301        0.519978
#  824               824        678976       1.709077        0.833338
#  825               825        680625       1.453139        0.971053
#
#  [766 rows x 239 columns],
#  'Lo Wu':           Date   Total      ex  hk_sum  hk_pc  hk_mobile  hk_food_sum  \
#  60  2023-04-07   67296  0.8749    7075   1418       5657          324
#  61  2023-04-08   81440  0.8749    7346    947       6399          292
#  62  2023-04-09  111824  0.8749    7098    928       6170          297
#  63  2023-04-10  121590  0.8765    7970   1588       6382          383
#  64  2023-04-11   69794  0.8773    7885   1432       6453          345
#  ..         ...     ...     ...     ...    ...        ...          ...
#  792 2025-04-08   82638  0.9444    5245    957       4288          261
#  793 2025-04-09   81359  0.9444    4868   1017       3851          221
#  794 2025-04-10   80281  0.9444    4985    981       4004          264
#  795 2025-04-11   82676  0.9444    4644    935       3709          219
#  796 2025-04-12   81797  0.9444    5116    741       4375          242
#
#       hk_food_pc  hk_food_mobile  hk_hotel_sum  ...  rolling_30_mean  \
#  60          110             214           307  ...     59054.600000
#  61           89             203           287  ...     59544.100000
#  62           78             219           269  ...     60441.333333
#  63          121             262           335  ...     62213.966667
#  64          116             229           351  ...     64050.366667
#  ..          ...             ...           ...  ...              ...
#  792          97             164           195  ...     95069.866667
#  793          82             139           201  ...     93232.500000
#  794         125             139           202  ...     92987.233333
#  795          70             149           182  ...     92956.000000
#  796          82             160           182  ...     93117.033333
#
#       ma_ratio_7_30  month_sin  month_cos  quarter_sin  quarter_cos  \
#  60        0.957654   0.866025       -0.5     0.866025          0.5
#  61        0.978830   0.866025       -0.5     0.866025          0.5
#  62        1.010668   0.866025       -0.5     0.866025          0.5
#  63        1.075167   0.866025       -0.5     0.866025          0.5
#  64        1.206029   0.866025       -0.5     0.866025          0.5
#  ..             ...        ...        ...          ...          ...
#  792       1.046489   0.866025       -0.5     0.866025          0.5
#  793       1.081464   0.866025       -0.5     0.866025          0.5
#  794       1.094442   0.866025       -0.5     0.866025          0.5
#  795       1.101655   0.866025       -0.5     0.866025          0.5
#  796       1.029677   0.866025       -0.5     0.866025          0.5
#
#       days_since_start  days_squared  weekly_growth  monthly_growth
#  60                 60          3600       0.946751        1.735249
#  61                 61          3721       0.984787        1.654518
#  62                 62          3844       0.920830        1.674519
#  63                 63          3969       0.926516        1.912841
#  64                 64          4096       0.823357        2.261221
#  ..                ...           ...            ...             ...
#  792               792        627264       0.921290        1.752347
#  793               793        628849       0.947318        0.960952
#  794               794        630436       0.952972        0.719456
#  795               795        632025       1.565046        0.976064
#  796               796        633616       1.144196        1.101841
#
#  [737 rows x 239 columns],
#  'Lok Ma Chau Spur Line':           Date  Total      ex  hk_sum   hk_pc  hk_mobile  hk_food_sum  \
#  60  2023-03-09  40149  0.8870  8193.0  1315.0     6878.0        348.0
#  61  2023-03-10  43580  0.8797  8289.0  1388.0     6901.0        294.0
#  62  2023-03-11  56021  0.8797  8695.0   948.0     7747.0        306.0
#  63  2023-03-12  66742  0.8797  8483.0   930.0     7553.0        315.0
#  64  2023-03-13  42251  0.8727  8215.0  1493.0     6722.0        355.0
#  ..         ...    ...     ...     ...     ...        ...          ...
#  820 2025-04-07  71906  0.9408  4751.0   952.0     3799.0        278.0
#  821 2025-04-08  68143  0.9444  5245.0   957.0     4288.0        261.0
#  823 2025-04-10  65681  0.9444  4985.0   981.0     4004.0        264.0
#  824 2025-04-11  68887  0.9444  4644.0   935.0     3709.0        219.0
#  825 2025-04-12  68802  0.9444  5116.0   741.0     4375.0        242.0
#
#       hk_food_pc  hk_food_mobile  hk_hotel_sum  ...  rolling_30_mean  \
#  60        101.0           247.0         276.0  ...     40510.633333
#  61         99.0           195.0         255.0  ...     40992.266667
#  62         78.0           228.0         253.0  ...     41527.200000
#  63         91.0           224.0         233.0  ...     42453.533333
#  64        123.0           232.0         305.0  ...     43615.533333
#  ..          ...             ...           ...  ...              ...
#  820       123.0           155.0         191.0  ...     80495.266667
#  821        97.0           164.0         195.0  ...     79788.600000
#  823       125.0           139.0         202.0  ...     78162.300000
#  824        70.0           149.0         182.0  ...     78094.733333
#  825        82.0           160.0         182.0  ...     78167.266667
#
#       ma_ratio_7_30  month_sin     month_cos  quarter_sin  quarter_cos  \
#  60        1.132919   1.000000  6.123234e-17     0.500000     0.866025
#  61        1.122529   1.000000  6.123234e-17     0.500000     0.866025
#  62        1.109727   1.000000  6.123234e-17     0.500000     0.866025
#  63        1.089756   1.000000  6.123234e-17     0.500000     0.866025
#  64        1.067031   1.000000  6.123234e-17     0.500000     0.866025
#  ..             ...        ...           ...          ...          ...
#  820       1.012489   0.866025 -5.000000e-01     0.866025     0.500000
#  821       1.029340   0.866025 -5.000000e-01     0.866025     0.500000
#  823       1.066813   0.866025 -5.000000e-01     0.866025     0.500000
#  824       1.070908   0.866025 -5.000000e-01     0.866025     0.500000
#  825       0.980319   0.866025 -5.000000e-01     0.866025     0.500000
#
#       days_since_start  days_squared  weekly_growth  monthly_growth
#  60                 60          3600       1.090579        4.524648
#  61                 61          3721       1.040411        4.265221
#  62                 62          3844       1.031961        3.569027
#  63                 63          3969       1.060107        3.709798
#  64                 64          4096       1.006882        3.626421
#  ..                ...           ...            ...             ...
#  820               820        672400       0.929653        1.474386
#  821               821        674041       0.940997        1.685724
#  823               823        677329       0.954974        0.708702
#  824               824        678976       1.705050        0.992546
#  825               825        680625       1.069038        1.059092
#
#  [765 rows x 239 columns],
#  'Shenzhen Bay':           Date  Total      ex  hk_sum  hk_pc  hk_mobile  hk_food_sum  \
#  60  2023-03-09  21565  0.8870    8193   1315       6878          348
#  61  2023-03-10  25148  0.8797    8289   1388       6901          294
#  62  2023-03-11  28530  0.8797    8695    948       7747          306
#  63  2023-03-12  40246  0.8797    8483    930       7553          315
#  64  2023-03-13  26269  0.8727    8215   1493       6722          355
#  ..         ...    ...     ...     ...    ...        ...          ...
#  821 2025-04-08  49906  0.9444    5245    957       4288          261
#  822 2025-04-09  47487  0.9444    4868   1017       3851          221
#  823 2025-04-10  50984  0.9444    4985    981       4004          264
#  824 2025-04-11  53957  0.9444    4644    935       3709          219
#  825 2025-04-12  51832  0.9444    5116    741       4375          242
#
#       hk_food_pc  hk_food_mobile  hk_hotel_sum  ...  rolling_30_mean  \
#  60          101             247           276  ...     22611.266667
#  61           99             195           255  ...     22874.166667
#  62           78             228           253  ...     23217.166667
#  63           91             224           233  ...     23668.400000
#  64          123             232           305  ...     24408.566667
#  ..          ...             ...           ...  ...              ...
#  821          97             164           195  ...     59617.833333
#  822          82             139           201  ...     58214.600000
#  823         125             139           202  ...     58056.466667
#  824          70             149           182  ...     58197.100000
#  825          82             160           182  ...     58464.700000
#
#       ma_ratio_7_30  month_sin     month_cos  quarter_sin  quarter_cos  \
#  60        1.129867   1.000000  6.123234e-17     0.500000     0.866025
#  61        1.118130   1.000000  6.123234e-17     0.500000     0.866025
#  62        1.104392   1.000000  6.123234e-17     0.500000     0.866025
#  63        1.085637   1.000000  6.123234e-17     0.500000     0.866025
#  64        1.068191   1.000000  6.123234e-17     0.500000     0.866025
#  ..             ...        ...           ...          ...          ...
#  821       1.067202   0.866025 -5.000000e-01     0.866025     0.500000
#  822       1.111616   0.866025 -5.000000e-01     0.866025     0.500000
#  823       1.125291   0.866025 -5.000000e-01     0.866025     0.500000
#  824       1.133054   0.866025 -5.000000e-01     0.866025     0.500000
#  825       1.050827   0.866025 -5.000000e-01     0.866025     0.500000
#
#       days_since_start  days_squared  weekly_growth  monthly_growth
#  60                 60          3600       1.060772        3.860570
#  61                 61          3721       1.036602        4.550689
#  62                 62          3844       1.043677        3.815013
#  63                 63          3969       1.063856        4.224069
#  64                 64          4096       0.991306        3.927833
#  ..                ...           ...            ...             ...
#  821               821        674041       0.904696        1.823286
#  822               822        675684       0.949678        0.874013
#  823               823        677329       0.992163        0.609777
#  824               824        678976       1.613035        0.986723
#  825               825        680625       1.115122        1.122331
#
#  [766 rows x 239 columns]}

# %%
import numpy as np
import joblib
import os
os.makedirs('models/round5', exist_ok=True)

# %%
for name, processed_data in list(processed_data_dict.items()):
    X_train, X_test, y_train, y_test = split_processed_data(processed_data)

    # 第一轮训练获取特征重要性
    best_models, stacking, mape = train_models(X_train, y_train, X_test, y_test)

    # 获取最优模型
    best_model_name = min(mape, key=mape.get)
    if best_model_name == 'stacking':
        best_model = stacking
    else:
        best_model = best_models[best_model_name]

    # 特征重要性筛选（修改部分）
    if best_model_name == 'stacking':
        # 使用第一个基模型的特征重要性
        base_model = best_model.estimators_[0]
        importance = base_model.feature_importances_
        features = base_model.feature_names_in_
    elif hasattr(best_model, 'feature_importances_'):
        importance = best_model.feature_importances_
        # 兼容不同模型的特征名称属性
        if hasattr(best_model, 'feature_names_in_'):  # sklearn
            features = best_model.feature_names_in_
        elif hasattr(best_model, 'feature_name_'):  # LightGBM
            features = best_model.feature_name_
        elif hasattr(best_model, 'feature_names_'):  # CatBoost
            features = best_model.feature_names_
        else:
            features = X_train.columns.tolist()
    elif hasattr(best_model, 'get_feature_importance'):
        importance = best_model.get_feature_importance()
        features = best_model.feature_names_
    else:
        features = X_train.columns.tolist()
        importance = np.ones(len(features))

    # 设置动态阈值
    sorted_idx = np.argsort(importance)[::-1]
    cumulative = np.cumsum(importance[sorted_idx])
    threshold_idx = np.where(cumulative >= 0.98 * cumulative[-1])[0][0]
    min_features = 10  # 最小保留特征数
    selected_features = [features[i] for i in sorted_idx[:max(threshold_idx+1, min_features)]]
    # 筛选特征后重新训练
    if len(selected_features) < len(features):
        print(f"{name} 特征筛选: 从 {len(features)} 个特征中保留 {len(selected_features)} 个")
        X_train_selected = X_train[selected_features]
        X_test_selected = X_test[selected_features]

        # 用筛选后的特征重新训练
        best_models, stacking, mape = train_models(X_train_selected, y_train, X_test_selected, y_test)
        best_model_name = min(mape, key=mape.get)
        if best_model_name == 'stacking':
            best_model = stacking
        else:
            best_model = best_models[best_model_name]

    # 保存模型
    filename = f"models/round5/{name}_best_{best_model_name}.pkl"
    # 保存模型和特征信息
    joblib.dump({
        'model': best_model,
        'features': selected_features if 'selected_features' in locals() else X_train.columns.tolist()
    },
        filename)
    stacking_filename = f"models/round5/{name}_stacking.pkl"
    joblib.dump(stacking, stacking_filename)
    print(f"{name} 最佳模型已保存：{filename} (MAPE={mape[best_model_name]:.4f})")
# Out:
# Hong Kong International Airport 特征筛选: 从 208 个特征中保留 21 个
# Hong Kong International Airport 最佳模型已保存：models/round5/Hong Kong International Airport_best_lgbm.pkl (MAPE=0.0500)
# Hong Kong-Zhuhai-Macao Bridge 特征筛选: 从 208 个特征中保留 112 个
# Hong Kong-Zhuhai-Macao Bridge 最佳模型已保存：models/round5/Hong Kong-Zhuhai-Macao Bridge_best_catboost.pkl (MAPE=0.0639)
# Lo Wu 特征筛选: 从 208 个特征中保留 124 个
# Lo Wu 最佳模型已保存：models/round5/Lo Wu_best_stacking.pkl (MAPE=0.0698)
# Lok Ma Chau Spur Line 特征筛选: 从 208 个特征中保留 91 个
# Lok Ma Chau Spur Line 最佳模型已保存：models/round5/Lok Ma Chau Spur Line_best_random_forest.pkl (MAPE=0.0498)
# Shenzhen Bay 特征筛选: 从 208 个特征中保留 133 个
# Shenzhen Bay 最佳模型已保存：models/round5/Shenzhen Bay_best_catboost.pkl (MAPE=0.1168)

# %%
models_path = ['models/round5/Hong Kong International Airport_best_lgbm.pkl',
              'models/round5/Hong Kong-Zhuhai-Macao Bridge_best_catboost.pkl',
              'models/round5/Lo Wu_best_stacking.pkl',
              'models/round5/Lok Ma Chau Spur Line_best_random_forest.pkl',
              'models/round5/Shenzhen Bay_best_catboost.pkl']

# %%
# 修改预测代码
for (name,df), model_path in zip(df_dict.items(), models_path):
    saved_data = joblib.load(model_path)
    model = saved_data['model']
    required_features = saved_data['features']
    print(name , forecast_future(df, model, 5, required_features)['Total'])
# Out:
# Hong Kong International Airport Date
# 2025-04-13    67039.625301
# 2025-04-14    62877.229371
# 2025-04-15    59892.141410
# 2025-04-16    57162.761164
# 2025-04-17    55271.965384
# Name: Total, dtype: float64
# Hong Kong-Zhuhai-Macao Bridge Date
# 2025-04-13    51707.914244
# 2025-04-14    35828.509138
# 2025-04-15    33121.825109
# 2025-04-16    32475.887737
# 2025-04-17    31783.814988
# Name: Total, dtype: float64
# Lo Wu Date
# 2025-04-13    121609.362402
# 2025-04-14     82613.676758
# 2025-04-15     84370.080601
# 2025-04-16     80754.390262
# 2025-04-17     80419.855881
# Name: Total, dtype: float64
# Lok Ma Chau Spur Line Date
# 2025-04-13    93293.662660
# 2025-04-14    72680.461451
# 2025-04-15    67265.166273
# 2025-04-16    66558.312612
# 2025-04-17    63993.076404
# Name: Total, dtype: float64
# Shenzhen Bay Date
# 2025-04-13    72927.376372
# 2025-04-14    52873.813738
# 2025-04-15    50478.021729
# 2025-04-16    52084.677143
# 2025-04-17    53801.764976
# Name: Total, dtype: float64

# %%
from statsforecast import StatsForecast
import numpy as np
import pandas as pd

# %%
step_list = [1, 1, 1, 3, 1]
result_dict = {}  # 用于存储所有预测结果

# %%
def process_portfolio(name, data, step):
    train, test = split_data(data)
    forecaster = RollingForecaster(train, test, steps=[step])
    metrics, predictions, ensemble_model = forecaster.run()

    # 选择最优模型
    avg_metrics = metrics.mean()
    forecaster.best_model_name = avg_metrics.idxmin()

    # 返回必要对象用于后续预测
    return {
        'name': name,
        'forecaster': forecaster,
        'ensemble_model': ensemble_model,
        'metrics': metrics,
        'data': data,
        'step': step
    }

# %%
for (name, data), step in zip(data_dict.items(), step_list):
    result = process_portfolio(name, data, step)
    result_dict[name] = result
    print(f"{name} 模型训练完成")
    print(f'MAPE: {result["metrics"]}')

# %%
def rolling_predict(data, model, days, horizon):
    predictions= [] # 定义预测结果
    # 循环预测
    for i in range(0, days, horizon):
        fcst = StatsForecast(
            models=[model],
            freq='D', # 时间频率(日)
        )
        forecast = fcst.forecast(
            df = data,
            h=horizon,
            time_col='Date',
            target_col='Total'
        )
        # 记录结果
        pred = forecast[model.__class__.__name__].values[:min(days-i, horizon)]
        predictions.extend(pred)
        pred_df = pd.DataFrame({
            'Date': pd.date_range(start=data['Date'].iloc[-1], periods=len(pred) + 1, freq='D')[1:],
            'Total': pred
        })
        data = pd.concat([data, pred_df])
    return predictions

# %%
total_horizon = 5  # 需要预测的总天数

for name, res in result_dict.items():
    # 解包存储的结果
    forecaster = res['forecaster']
    data = res['data']
    step = res['step']

    current_step = step   # 从验证时使用的步长
    metrics_min = res['metrics'].loc[current_step].min()
    data_with_id = data.copy()
    data_with_id.insert(0, 'unique_id', 1)
    if forecaster.best_model_name == 'Ensemble':
        ensemble_model = res['ensemble_model']
        models_preds = []
        remaining = total_horizon
        for model in forecaster.models:
            models_preds.append(rolling_predict(data_with_id, model, total_horizon, current_step))
        X_stack = np.column_stack(models_preds)
        final_pred = ensemble_model.predict(X_stack)[:total_horizon]
    else:
        best_model = forecaster.models[forecaster.model_names.index(forecaster.best_model_name)]
        final_pred = forecaster.rolling_predict(data_with_id, best_model, total_horizon, current_step)
    print(f'{name}: 未来5天预测结果{final_pred} ')
    print(f'MAPE: {metrics_min} MODEL: {forecaster.best_model_name}')
# Out:
# Hong Kong International Airport: 未来5天预测结果[61585.777, 61585.77722597111, 61585.77722597111, 61585.77722597111, 61585.77722597111] //MAPE: 0.037983183305263735 MODEL: MSTL
# Hong Kong-Zhuhai-Macao Bridge: 未来5天预测结果[39559.81, 39559.80922183904, 39559.80922183904, 39559.80922183904, 39559.80922183904] //MAPE: 0.08011649323770763 MODEL: MSTL
# Lo Wu: 未来5天预测结果[100815.664, 100815.66237434547, 100815.66237434547, 100815.66237434547, 100815.66237434547] //MAPE: 0.05052347689658431 MODEL: SARIMA
# Lok Ma Chau Spur Line: 未来5天预测结果[88692.53, 104565.086, 71651.36, 88692.52802815495, 104565.08390007247] //MAPE: 0.05285953770950711 MODEL: SARIMA
# Shenzhen Bay: 未来5天预测结果[67752.75, 67752.74775698064, 67752.74775698064, 67752.74775698064, 67752.74775698064] //MAPE: 0.07233163912953892 MODEL: SARIMA
